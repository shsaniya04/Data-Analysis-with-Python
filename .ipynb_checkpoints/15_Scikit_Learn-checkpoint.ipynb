# %% [markdown]
# ### Datasets

# %% [raw]
# from sklearn.datasets import load_breast_cancer, fetch_california_housing, fetch_openml, make_blobs, make_moons

# %% [markdown]
# ### Splitting data

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
X, y = load_iris(return_X_y = True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2) # 20% testing, 80% training

# %%
len(X_train)
# Out:
# 120

# %%
len(X_test)
# Out:
# 30

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
counts = np.bincount(y_train)
positions = np.arange(3)

# %%
plt.bar(positions, counts)
plt.xticks(positions, counts);
