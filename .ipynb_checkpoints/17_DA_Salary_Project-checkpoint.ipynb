# %% [markdown]
# # **Tech Job Market & Salary Predictors Analysis**

# %% [markdown]
# ## **Data Wrangling**

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns  

plt.style.use("default")
sns.set_context("notebook")

# %%
df = pd.read_csv("salary_data.csv")

# %%
df.head()
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location Employment Status Job Roles
# 0                  3  Bangalore         Full Time   Android
# 1                  3  Bangalore         Full Time   Android
# 2                  3  Bangalore         Full Time   Android
# 3                  3  Bangalore         Full Time   Android
# 4                  3  Bangalore         Full Time   Android

# %%
df.tail()
# Out:
#        Rating             Company Name                 Job Title  Salary  \
# 22765     4.7         Expert Solutions             Web Developer  200000
# 22766     4.0  Nextgen Innovation Labs             Web Developer  300000
# 22767     4.1                  Fresher  Full Stack Web Developer  192000
# 22768     4.1                Accenture  Full Stack Web Developer  300000
# 22769     3.8          Thomson Reuters   Associate Web Developer  300000
#
#        Salaries Reported   Location Employment Status Job Roles
# 22765                  1  Bangalore         Full Time       Web
# 22766                  1  Bangalore         Full Time       Web
# 22767                 13  Bangalore         Full Time       Web
# 22768                  7  Bangalore         Full Time       Web
# 22769                  7  Bangalore         Full Time       Web

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22770 entries, 0 to 22769
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             22770 non-null  float64
#  1   Company Name       22769 non-null  str
#  2   Job Title          22770 non-null  str
#  3   Salary             22770 non-null  int64
#  4   Salaries Reported  22770 non-null  int64
#  5   Location           22770 non-null  str
#  6   Employment Status  22770 non-null  str
#  7   Job Roles          22770 non-null  str
# dtypes: float64(1), int64(2), str(5)
# memory usage: 1.4 MB

# %%
df.describe()
# Out:
#              Rating        Salary  Salaries Reported
# count  22770.000000  2.277000e+04       22770.000000
# mean       3.918213  6.953872e+05           1.855775
# std        0.519675  8.843990e+05           6.823668
# min        1.000000  2.112000e+03           1.000000
# 25%        3.700000  3.000000e+05           1.000000
# 50%        3.900000  5.000000e+05           1.000000
# 75%        4.200000  9.000000e+05           1.000000
# max        5.000000  9.000000e+07         361.000000

# %%
df.shape
# Out:
# (22770, 8)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=22770, step=1)

# %%
df.columns = df.columns.str.replace(" ", "")

# %%
df.nunique()
# Out:
# Rating                 41
# CompanyName         11260
# JobTitle             1080
# Salary                316
# SalariesReported       82
# Location               10
# EmploymentStatus        4
# JobRoles               11
# dtype: int64

# %%
df.Location.value_counts()
# Out:
# Location
# Bangalore         8264
# Hyderabad         4467
# New Delhi         4176
# Chennai           2458
# Pune              2134
# Mumbai             749
# Kolkata            178
# Madhya Pradesh     155
# Kerala             108
# Jaipur              81
# Name: count, dtype: int64

# %%
df.JobRoles.value_counts()
# Out:
# JobRoles
# SDE         8183
# Android     2945
# Frontend    2163
# Java        1858
# Testing     1740
# IOS         1631
# Backend     1194
# Web          999
# Python       947
# Database     865
# Mobile       245
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Rating              0
# CompanyName         1
# JobTitle            0
# Salary              0
# SalariesReported    0
# Location            0
# EmploymentStatus    0
# JobRoles            0
# dtype: int64

# %%
df.head()
# Out:
#    Rating                       CompanyName           JobTitle   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    SalariesReported   Location EmploymentStatus JobRoles
# 0                 3  Bangalore        Full Time  Android
# 1                 3  Bangalore        Full Time  Android
# 2                 3  Bangalore        Full Time  Android
# 3                 3  Bangalore        Full Time  Android
# 4                 3  Bangalore        Full Time  Android

# %%
df.drop_duplicates()
# Out:
#        Rating                       CompanyName                  JobTitle  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  SalariesReported   Location EmploymentStatus JobRoles
# ...

# %%
plt.figure(figsize = (4,3))
sns.boxplot(x = df['Salary'])
plt.title("Salary Outliers")
plt.show()

# %% [raw]
# conditions = [
#     (df['SalariesReported'] <= 3),
#     (df['SalariesReported'] > 3) & (df['SalariesReported'] <= 10),
#     (df['SalariesReported'] > 10)
# ]
#
# choices = ['Low', 'Medium', 'High']
#
# df['SalaryConfidence'] = np.select(conditions, choices, default = "Unknown")

# %% [markdown]
# **IQR (Interquartile Range) Method**

# %%
Q1 = df['Salary'].quantile(0.25)
Q3 = df['Salary'].quantile(0.75)

IQR = Q3 - Q1

# %%
lower_limit = Q1 - 1.5 * IQR 

upper_limit = Q3 + 1.5 * IQR

# %%
df = df[(df['Salary'] >= lower_limit) & (df['Salary'] <= upper_limit)]

# %%
df
# Out:
#        Rating                       CompanyName                  JobTitle  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  SalariesReported   Location EmploymentStatus JobRoles
# ...

# %% [markdown]
# ### **AFTER REMOVING OUTLIERS**

# %%
plt.figure(figsize = (6, 4))
sns.boxplot(x = df['Salary'])

plt.title("Salary Outliers") 
plt.show();

# %% [markdown]
# ### **AGAIN REMOVE OUTLIERS**

# %%
Q1 = df['Salary'].quantile(0.25)
Q3 = df['Salary'].quantile(0.75)

IQR = Q3 - Q1

# %%
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

# %%
df = df[(df['Salary'] >= lower_limit) & (df['Salary'] <= upper_limit)]

# %%
df.shape
# Out:
# (21014, 8)

# %%
plt.figure(figsize = (6, 4))
sns.boxplot(x = df['Salary'])

plt.title("Salary Outliers") 
plt.show();

# %% [markdown]
# ## **UNIVARIATE ANALYSIS**

# %% [markdown]
# ### **SALARY DISTRIBUTION**

# %%
plt.figure(figsize = (8, 5))
sns.histplot(x = df['Salary'], bins = 30, kde = True)

# this line of code makes x - axis data in general format
plt.ticklabel_format(style = 'plain', axis = 'x')

plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Count")
plt.show();

# %% [markdown]
# ### **JOB ROLES HAVING HIGHEST SALARY**

# %%
job_salary = df.groupby('JobRoles')['Salary'].mean().sort_values(ascending = False)

# %%
plt.figure(figsize = (8, 5))
job_salary.plot(kind = 'bar')
plt.title("Top 10 Job Roles by Average Salary")
plt.ylabel("Average Salary") 
plt.show()

# %% [markdown]
# ### **CITIES HAVE HIGHEST AVERAGE SALARY**

# %%
df.head(2)
# Out:
#    Rating                       CompanyName           JobTitle  Salary  \
# 0     3.8                            Sasken  Android Developer  400000
# 1     4.5  Advanced Millennium Technologies  Android Developer  400000
#
#    SalariesReported   Location EmploymentStatus JobRoles
# 0                 3  Bangalore        Full Time  Android
# 1                 3  Bangalore        Full Time  Android

# %%
city_salary = df.groupby("Location")['Salary'].mean().sort_values(ascending = False)
city_salary
# Out:
# Location
# Mumbai            702195.874214
# Bangalore         568223.271851
# Jaipur            566153.846154
# Pune              562387.138833
# New Delhi         542717.057751
# Hyderabad         538809.567450
# Kolkata           532604.938272
# Kerala            514965.735849
# Chennai           505102.446337
# Madhya Pradesh    497530.378378
# Name: Salary, dtype: float64

# %%
plt.figure(figsize = (10, 5))
colors = sns.color_palette("viridis", len(city_salary))
city_salary.plot(kind = 'bar', color = colors, edgecolor = 'black')
plt.title("Top 10 Cities by Average Salary", fontsize = 15, fontweight = 'bold')
plt.xlabel("City")
plt.ylabel("Average Salary")
plt.xticks(rotation = 15, ha = 'right')
plt.grid(axis = "y", linestyle = "--", alpha = 0.5)
plt.show()

# %% [markdown]
# ### **5 companies with `location Delhi` and with `rating 5` offering highest and lowest salaries**

# %%
df_delhi = df[(df['Location'] == 'New Delhi') & (df['Rating'] == 5)].sort_values(by = 'Salary', ascending = False)

# %%
df_delhi
# Out:
#        Rating               CompanyName  \
# 1888      5.0                  Trillbit
# 6750      5.0                   Hapramp
# 17488     5.0   The Art of Mike Mignola
# 8284      5.0  Silicon Valley Recycling
# 17351     5.0           Parth Universal
# ...       ...                       ...
# 8008      5.0                   Rabbler
# 1969      5.0             WorkingNation
# 2334      5.0             Hopin (India)
# 17524     5.0            Star Catalysts
# 18680     5.0                    Atom 8
#
#                                            JobTitle   Salary  \
# 1888                              Android Developer  1500000
# 6750                            Front End Developer  1500000
# 17488                 Software Development Engineer  1500000
# 8284                           Senior IOS Developer  1400000
# 17351                 Software Development Engineer  1300000
# ...                                             ...      ...
# ...

# %%
list(df_delhi['CompanyName'].head())
# Out:
# ['Trillbit',
#  'Hapramp',
#  'The Art of Mike Mignola',
#  'Silicon Valley Recycling',
#  'Parth Universal']

# %%
list(df_delhi['CompanyName'].tail())
# Out:
# ['Rabbler', 'WorkingNation', 'Hopin (India)', 'Star Catalysts', 'Atom 8']

# %% [markdown]
# ### **Job Title - highest number of salary reported**

# %%
df['JobTitle'].value_counts()
# Out:
# JobTitle
# Software Development Engineer          2137
# Android Developer                      1983
# Software Development Engineer (SDE)    1477
# Front End Developer                    1360
# Test Engineer                          1290
#                                        ...
# Software Engineer In Test                 1
# Test Engineer II                          1
# Software Tester - Contractor              1
# Software Tester Contractor                1
# Associate Web Developer                   1
# Name: count, Length: 981, dtype: int64

# %%
df.groupby("JobTitle")['SalariesReported'].count().sort_values(ascending = False)
# Out:
# JobTitle
# Software Development Engineer                        2137
# Android Developer                                    1983
# Software Development Engineer (SDE)                  1477
# Front End Developer                                  1360
# Test Engineer                                        1290
#                                                      ...
# UI/User Experience Designer & Front End Developer       1
# UI/UX Designer & Front End Developer                    1
# UI Front End Developer                                  1
# Trainee Test Engineer - Contractor                      1
# Trainee Engineer – Software Development                 1
# Name: SalariesReported, Length: 981, dtype: int64

# %% [markdown]
# ### **10 companies - highest average salary, when at least 20 employees have reported their salaries**

# %%
df_slry_rep = df[df['SalariesReported'] >= 20]

# %%
df_slry_rep
# Out:
#        Rating                     CompanyName                  JobTitle  \
# 8790      3.9       Tata Consultancy Services            Java Developer
# 8977      3.8  Cognizant Technology Solutions     Senior Java Developer
# 8978      3.9       Tata Consultancy Services     Senior Java Developer
# 8979      3.9       Tata Consultancy Services     Junior Java Developer
# 9688      3.9       Tata Consultancy Services            Java Developer
# ...       ...                             ...                       ...
# 21762     3.8                             CGI      Senior Test Engineer
# 21763     4.1                             IBM  Test Automation Engineer
# 21764     3.7                       SLK Group    Software Test Engineer
# 21765     4.3                   Cisco Systems    Software Test Engineer
# 21772     3.9       Tata Consultancy Services             Web Developer
#
#        Salary  SalariesReported   Location EmploymentStatus JobRoles
# ...

# %%
df_slry_rep.groupby("CompanyName")['Salary'].mean().sort_values(ascending = False).head(10)
# Out:
# CompanyName
# Expedia Group     1.350000e+06
# Nokia             1.200000e+06
# Amadeus           1.200000e+06
# Alcatel-Lucent    1.000000e+06
# Ola               1.000000e+06
# Kony              9.000000e+05
# Lumen             9.000000e+05
# Microsoft         7.845714e+05
# Cisco Systems     7.000000e+05
# McAfee            6.500000e+05
# Name: Salary, dtype: float64

# %% [markdown]
# ### **Check and show relationship between ratings and salaries**

# %%
df.select_dtypes(include='number').corr()
# Out:
#                     Rating    Salary  SalariesReported
# Rating            1.000000  0.024772         -0.013516
# Salary            0.024772  1.000000         -0.021672
# SalariesReported -0.013516 -0.021672          1.000000

# %%
df['Rating'].corr(df['Salary'])
# Out:
# np.float64(0.02477162838343561)

# %%
sns.relplot(x = 'Rating', y = 'Salary', data = df)
plt.show()

# %%
sns.regplot(x = 'Rating', y = 'Salary', data = df, scatter_kws = {"alpha" : 0.5, "color" : "teal"}, line_kws = {"linewidth" : 2})

plt.title("Rating vs Salary (With Trend Line)", fontsize = 14, fontweight = "bold")
plt.xlabel("Company Rating")
plt.ylabel("Salary")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Employment status affect salary?**

# %%
df['EmploymentStatus'].unique()
# Out:
# <StringArray>
# ['Full Time', 'Intern', 'Contractor', 'Trainee']
# Length: 4, dtype: str

# %%
df['EmploymentStatus'].value_counts()
# Out:
# EmploymentStatus
# Full Time     18379
# Intern         2089
# Contractor      513
# Trainee          33
# Name: count, dtype: int64

# %%
df.groupby("EmploymentStatus")['Salary'].describe()
# Out:
#                     count           mean            std      min       25%  \
# EmploymentStatus
# Contractor          513.0  501507.586745  315663.813209  12000.0  300000.0
# Full Time         18379.0  579305.536101  358065.460032   8448.0  300000.0
# Intern             2089.0  338353.991383  264180.887035   2112.0  144000.0
# Trainee              33.0  324303.030303  241096.516572  96000.0  144000.0
#
#                        50%       75%        max
# EmploymentStatus
# Contractor        400000.0  600000.0  1500000.0
# Full Time         500000.0  800000.0  1550000.0
# Intern            264000.0  456000.0  1500000.0
# Trainee           240000.0  400000.0  1100000.0

# %%
plt.figure(figsize=(6, 5))

colors = ['blue', 'orange', 'green', 'red']

sns.boxplot(x='EmploymentStatus', y='Salary', hue='EmploymentStatus', data=df, palette=colors, legend=False)

plt.title("Employment Status vs Salary")
plt.xlabel("Employment Type")
plt.ylabel("Salary")

plt.show()

# %% [markdown]
# ### **Most common job roles**

# %%
df['JobRoles'].value_counts()
# Out:
# JobRoles
# SDE         7245
# Android     2812
# Frontend    2034
# Java        1778
# Testing     1710
# IOS         1524
# Backend     1049
# Web          988
# Python       929
# Database     734
# Mobile       211
# Name: count, dtype: int64

# %%
df_job_roles = df['JobRoles'].value_counts().head(10)

# %%
plt.figure(figsize=(10,6))

# Gradient colors
colors = sns.color_palette("hsv", n_colors=len(df_job_roles))

# Horizontal Bar Chart
plt.barh(
    df_job_roles.index,
    df_job_roles.values,
    color=colors,
    edgecolor='red'
)

# Add value labels
for i, v in enumerate(df_job_roles.values):
    plt.text(
        x=v + 50,
        y=i,
        s=str(v),
        va='center',
        fontweight='bold'
    )

plt.xlabel("Count")
plt.ylabel("Job Roles")
plt.title("Job Roles Distribution")

plt.show()

# %%
df_slry_rating = df.groupby("Rating")['Salary'].mean().reset_index()
df_slry_rating
# Out:
#     Rating         Salary
# 0     1.00  399971.500000
# 1     1.30  500000.000000
# 2     1.40  331200.000000
# 3     1.50  241000.000000
# 4     1.60  262285.714286
# 5     1.70  750000.000000
# 6     1.80  330333.333333
# 7     1.90  438666.666667
# 8     2.00  437481.481481
# 9     2.10  465866.666667
# 10    2.20  365900.000000
# 11    2.30  399714.285714
# 12    2.40  486775.510204
# 13    2.50  511524.500000
# 14    2.60  437398.794521
# 15    2.70  463741.935484
# 16    2.80  495081.967213
# 17    2.90  476463.337278
# 18    3.00  456706.342679
# 19    3.10  557508.090615
# 20    3.20  524166.272425
# 21    3.30  528559.855422
# 22    3.40  581967.586716
# 23    3.50  526050.402145
# 24    3.60  563728.342246
# 25    3.70  569438.949495
# 26    3.80  581869.033943
# 27    3.85  598909.090909
# 28    3.90  581744.937858
# 29    3.95  392307.692308
# 30    4.00  541831.842321
# 31    4.10  580753.883333
# 32    4.20  570572.511278
# 33    4.30  567373.466437
# ...

# %%
plt.figure(figsize = (7, 5)) 
sns.lineplot(x = 'Rating', y = 'Salary', data = df_slry_rating, marker = 'o') 

plt.title("Average Salary Trend Across Company Rating", fontsize = 14, fontweight = 'bold')
plt.xlabel("Company Rating")
plt.ylabel("Average Salary")
plt.show()
