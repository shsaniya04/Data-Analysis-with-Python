# %%
# Arithmetic and Logical Operators
a, b = 15, 4
print(a//b, a%b, a**b)
# Out:
# 3 3 50625

# %%
# Calculations and Condition
num = int(input("Enter an Integer: "))

div_3 = (num % 3 == 0)
div_5 = (num % 5 == 0) 

if div_3 and div_5:
    print("Divisible by 3 and 5.")
elif (div_3 or div_5) and not (div_3 and div_5):
    print("Divisible by only one.")
elif not div_3 and not div_5:
    print("Divisible by none.")
# Out:
# Enter an Integer:  4
# Divisible by none.

# %%
# Precedence Check
print(10 > 5 and 5 > 8 or 3 == 3)
# Out:
# True

# %%
#  Login System - Logics and Conditions
correct_username = "admin"
correct_password = 1234

username = str(input("Enter username: "))
password = int(input("Enter password: "))

if username == correct_username and password == correct_password:
    print("Login sucessfull!")
else: 
    print("Access denied! Please check username or password.")
# Out:
# Enter username:  sdc
# Enter password:  1234
# Access denied! Please check username or password.

# %%
# Swap three variables
a, b, c = 10, 20, 30

a,b,c = b,c,a

print(a,b,c)
# Out:
# 20 30 10

# %%
# Precedence check
x = 5
x += 3 * 2
x
# Out:
# 11

# %%
# data type challenge
a = 5
b = "5"

c = a + int(b)
d = a * int(b)
print(c, d)
# Out:
# 10 25

# %%
# Output Formatting
name = "Saniya"
score = 92.4567
print("Name: {} | Score: {:.2f}".format(name, score))
# Out:
# Name: Saniya | Score: 92.46

# %%
# Reverse a string
word = "Saniya"

char_list  = list(word)

char_list.reverse()

reverse_word = "".join(char_list)

print("String: {} | Reversed String: {}".format(word, reverse_word))
# Out:
# String: Saniya | Reversed String: ayinaS

# %%
# String Counting
text = "dadsgvCTFGDAD12345698876312"

upper_count = 0
lower_count = 0
digit_count = 0

for char in text:
    if char.isupper():
        upper_count += 1
    elif char.islower():
        lower_count += 1
    elif char.isdigit():
        digit_count += 1

print("Upper Count : {} | Lower Count: {} | Digits: {}".format(upper_count, lower_count, digit_count))
# Out:
# Upper Count : 7 | Lower Count: 6 | Digits: 14

# %%
# Capitalize
text = "data science is fun"

print(text.capitalize())
print(text.title())
# Out:
# Data science is fun
# Data Science Is Fun

# %%
# Cpitalize without using title function 
text = "data science is fun"

words = text.split(" ")

capitalize_words = []
for word in words:
    capitalize_words.append(word.capitalize())

result = " ".join(capitalize_words)
print(result)
# Out:
# Data Science Is Fun

# %%
# Space with _ underscore
text = "data science if fun"

if len(text) > 10:
    text = text.replace(" ", "_")

print(text)
# Out:
# data_science_if_fun

# %%
# Find first non repeating character
text = "aaabbbcccd"

for char in text:
    if text.count(char) == 1:
        print("First non repeating character:", char)
        break
# Out:
# First non repeating character: d

# %%
# Rotate list left by 1
nums = [10, 20, 30, 40, 50] 
first_element = nums.pop(0)
nums.append(first_element)

print(nums)

number = [10, 20, 30, 40, 50] 
number = number[1:] + number[:1]
print(number)
# Out:
# [20, 30, 40, 50, 10]
# [20, 30, 40, 50, 10]

# %%
# Remove duplicate
nums = [10, 20, 20, 30, 40, 50, 50]
unique_list = []

for item in nums:
    if item not in unique_list:
        unique_list.append(item)

print(unique_list)
# Out:
# [10, 20, 30, 40, 50]

# %%
# Find second largest number
nums = [10, 20, 4, 45, 99, 99, 27]
largest_num = max(nums)
while largest_num in nums:
    nums.remove(largest_num)

second_largest = max(nums)

print(second_largest)
# Out:
# 45

# %%
# Split
nums = [1,2,3,4,5,6]
odd_list = []
even_list = []
# Out:
# Object `nums = nums.split()` not found.
