# %% [markdown]
# ## Arithmetic Operation
# ### Python Operators
#
# | Operator   | Purpose           | Example     | Result    |
# |------------|-------------------|-------------|-----------|
# | `+`        | Addition          | `2 + 3`     | `5`       |
# | `-`        | Subtraction       | `3 - 2`     | `1`       |
# | `*`        | Multiplication    | `8 * 12`    | `96`      |
# | `/`        | Division          | `100 / 7`   | `14.28..` |
# | `//`       | Floor Division    | `100 // 7`  | `14`      |
# | `%`        | Modulus/Remainder | `100 % 7`   | `2`       |
# | `**`       | Exponent          | `5 ** 3`    | `125`     |

# %%
5 + 4 + 2 + 7
# Out:
# 18

# %%
100 - 73
# Out:
# 27

# %%
27 * 2
# Out:
# 54

# %%
100 / 7
# Out:
# 14.285714285714286

# %%
100 // 7
# Out:
# 14

# %%
100 % 7
# Out:
# 2

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# As you might expect, certain operators like `/`and `*` take precendence over other operators like `+` and `-` as per mathematical conventions. You can use parantheses i.e. `(` and `)` to specify the order in which operations are performed.

# %%
((5 * 4) + (10 // 3)) * ((234 - 43) / ( 98 + 2))
# Out:
# 43.93

# %% [markdown]
# ### Solving multi-step problems using variables

# %%
cost_of_ice_bag = 1.25

# %%
profit_margin = .2

# %%
no_of_bags = 500

# %%
profit_per_bag = profit_margin * cost_of_ice_bag

# %%
profit_per_bag
# Out:
# 0.25

# %%
total_profit = profit_per_bag * no_of_bags

# %%
total_profit
# Out:
# 125.0

# %%
print("The grocery store makes a total profit of $", total_profit)
# Out:
# The grocery store makes a total profit of $ 125.0

# %%
# Store input data variables
cost_of_ice_bag = 1.25
profit_margin = .2
no_of_bags = 500

# Perform calculations
profit_per_bag = profit_margin * cost_of_ice_bag
total_profit = profit_per_bag * no_of_bags

# Display result
print("The grocery store makes a total profit of $", total_profit)
# Out:
# The grocery store makes a total profit of $ 125.0

# %%
# Store input data variables
population_of_town = 198568
no_of_men = 45312
no_of_women = 35678

# Perform calculations
total_adults = no_of_men + no_of_women
no_of_children = population_of_town - total_adults

# Display result
print("The total no of children present in town is ", no_of_children)
# Out:
# The total no of children present in town is  117578

# %%
# Store input data variables
no_of_boxes = 2425
pencil_per_box = 24

# Perform calculations
total_pencil = no_of_boxes * pencil_per_box

# Display result
print("The total no of pencil do all the boxes have in all is ", total_pencil)
# Out:
# The total no of pencil do all the boxes have in all is  58200

# %% [markdown]
# ## Condition Operators
# ### Evaluating conditions using Python
#
# | Operator    | Description                                                     |
# |-------------|-----------------------------------------------------------------|
# | `==`        | Check if operands are equal                                     |
# | `!=`        | Check if operands are not equal                                 |
# | `>`         | Check if left operand is greater than right operand             |
# | `<`         | Check if left operand is less than right operand                |
# | `>=`        | Check if left operand is greater than or equal to right operand |
# | `<=`        | Check if left operand is less than or equal to right operand    |

# %%
# assih=gn values
high_no = 54
medium_no = 27
low_no = 9

# apply condition operators

# %%
high_no == 54
# Out:
# True

# %%
high_no == low_no
# Out:
# False

# %%
medium_no != low_no
# Out:
# True

# %%
medium_no != 27
# Out:
# False

# %%
high_no >= low_no
# Out:
# True

# %%
medium_no >= high_no
# Out:
# False

# %%
low_no <= medium_no
# Out:
# True

# %%
high_no <= medium_no
# Out:
# False

# %%
high_no > low_no
# Out:
# True

# %%
medium_no > high_no
# Out:
# False

# %%
low_no < high_no
# Out:
# True

# %%
medium_no < low_no
# Out:
# False

# %%
9 + 27 >= 54
# Out:
# False

# %%
9 + 27 <= 54
# Out:
# True

# %%
# problems condition check 
cost_of_ice_bag = 1.25
is_ice_bag_cheap = cost_of_ice_bag <= 3
print("Is the ice bag cheap?", is_ice_bag_cheap)
# Out:
# Is the ice bag cheap? True

# %% [markdown]
# ## Logical Operators
# ### Combining conditions with logical operators
#
# The logical operators `and`, `or` and `not` operate upon conditions and `True` & `False` values (also known as *booleans*). `and` and `or` operate on two conditions, whereas `not` operates on a single condition.

# %%
# AND
high_no > 0 and low_no < 8
# Out:
# False

# %%
# OR
medium_no > 30 or low_no > 6
# Out:
# True

# %%
# NOT
not medium_no != 27
# Out:
# True

# %% [markdown]
# ## Variables
# ### Storing information using variables
# * storing information (also known as data) and performing operations on stored data

# %%
my_color = "Black"
my_color
# Out:
# 'Black'

# %%
color1, color2, color3 = "Red", "Blue", "Green"

# %%
color2
# Out:
# 'Blue'

# %%
color4 = color5 = color6 = "Magenta"

# %%
color6
# Out:
# 'Magenta'

# %%
my_color = "White"

# %%
my_color
# Out:
# 'White'

# %%
counter = 15

# %%
counter
# Out:
# 15

# %%
counter = counter + 5

# %%
counter
# Out:
# 20

# %%
counter -= 5

# %%
counter
# Out:
# 15

# %% [markdown]
# ## Data Types
# ## Built-in data types in Python
#
# Any data or information stored within a Python variable has a *type*. You can view the type of data stored within a variable using the `type` function.
#
# Python has several built-in data types for storing different kinds of information in variables. Following are some commonly used data types:
#
# 1. Integer
# 2. Float
# 3. Boolean
# 4. None
# 5. String
# 6. List
# 7. Tuple
# 8. Dictionary
#
# Integer, float, boolean, None, and string are *primitive data types* because they represent a single value. Other data types like list, tuple, and dictionary are often called *data structures* or *containers* because they hold multiple pieces of data together.

# %% [markdown]
# ### Integer
#
# Integers represent positive or negative whole numbers, from negative infinity to infinity. Note that integers should not include decimal points. Integers have the type `int`.

# %%
current_year = 2026

# %%
current_year
# Out:
# 2026

# %%
type(current_year)
# Out:
# int

# %%
# can be arbitrarily large (or small
large_negative_no = -345678987654323456789876543234567876543

# %%
large_negative_no
# Out:
# -345678987654323456789876543234567876543

# %%
type(large_negative_no)
# Out:
# int

# %% [markdown]
# ### Float
#
# Floats (or floating-point numbers) are numbers with a decimal point. There are no limits on the value or the number of digits before or after the decimal point. Floating-point numbers have the type `float`.

# %%
pi = 3.141592653589793238

# %%
pi
# Out:
# 3.141592653589793

# %%
type(pi)
# Out:
# float

# %% [markdown]
# Note that a whole number is treated as a float if written with a decimal point, even though the decimal portion of the number is zero.

# %%
dec_number = 3.0

# %%
dec_number
# Out:
# 3.0

# %%
type(dec_number)
# Out:
# float

# %% [markdown]
# Floating point numbers can also be written using the scientific notation with an "e" to indicate the power of 10.

# %%
avogadro_number = 6.02214076e23

# %%
avogadro_number
# Out:
# 6.02214076e+23

# %%
type(avogadro_number)
# Out:
# float

# %% [markdown]
# While performing arithmetic operations, integers are automatically converted to `float`s if any of the operands is a `float`. Also, the division operator `/` always returns a `float`, even if both operands are integers. Use the `//` operator if you want the result of the division to be an `int`.

# %%
type(32 * 6.3)
# Out:
# float

# %%
type(2 * 3)
# Out:
# int

# %%
  type(10 / 3)
# Out:
# float

# %%
type(10 / 2)
# Out:
# float

# %%
type(10 // 2)
# Out:
# int

# %% [markdown]
# ### Boolean
#
# Booleans represent one of 2 values: `True` and `False`. Booleans have the type `bool`.

# %%
is_today_Friday = True

# %%
is_today_Friday
# Out:
# True

# %%
type(is_today_Friday)
# Out:
# bool

# %% [markdown]
# Booleans are generally the result of a comparison operation, e.g., `==`, `>=`, etc.

# %%
cost_of_ice_bag = 1.25
is_ice_bag_cheap = cost_of_ice_bag <= 3

# %%
is_ice_bag_cheap
# Out:
# True

# %%
type(is_ice_bag_cheap)
# Out:
# bool

# %% [markdown]
# Booleans are automatically converted to `int`s when used in arithmetic operations. `True` is converted to `1` and `False` is converted to `0`.

# %%
4 + False
# Out:
# 4

# %%
3. + True
# Out:
# 4.0

# %% [markdown]
# Any value in Python can be converted to a Boolean using the `bool` function.
#
# Only the following values evaluate to `False` (they are often called *falsy* values):
#
# 1. The value `False` itself
# 2. The integer `0`
# 3. The float `0.0`
# 4. The empty value `None`
# 5. The empty text `""`
# 6. The empty list `[]`
# 7. The empty tuple `()`
# 8. The empty dictionary `{}`
# 9. The empty set `set()`
# 10. The empty range `range(0)`
#
# Everything else evaluates to `True` (a value that evaluates to `True` is often called a *truthy* value).

# %%
bool(False)
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(None)
# Out:
# False

# %%
bool("")
# Out:
# False

# %%
bool([])
# Out:
# False

# %%
bool(())
# Out:
# False

# %%
bool({})
# Out:
# False

# %%
bool(set())
# Out:
# False

# %%
bool(range(0))
# Out:
# False

# %%
bool(True), bool(1), bool(4.0), bool("hello"), bool([1,2]), bool((5,6)), bool(range(10))
# Out:
# (True, True, True, True, True, True, True)

# %% [markdown]
# ### None
#
# The None type includes a single value `None`, used to indicate the absence of a value. `None` has the type `NoneType`. It is often used to declare a variable whose value may be assigned later.

# %%
nothing = None

# %%
type(nothing)
# Out:
# NoneType

# %% [markdown]
# ### String
#
# A string is used to represent text (*a string of characters*) in Python. Strings must be surrounded using quotations (either the single quote `'` or the double quote `"`). Strings have the type `string`.

# %%
today = "Friday"

# %%
today
# Out:
# 'Friday'

# %%
type(today)
# Out:
# str

# %% [markdown]
# You can use single quotes inside a string written with double quotes, and vice versa.

# %%
my_favorite_series = "Yeralti - Underground"

# %%
my_favorite_series
# Out:
# 'Yeralti - Underground'

# %%
my_favorite_pun = 'Thanks for explaining the word "many" to me, it means a lot.'

# %%
my_favorite_pun
# Out:
# 'Thanks for explaining the word "many" to me, it means a lot.'

# %% [markdown]
# To use a double quote within a string written with double quotes, *escape* the inner quotes by prefixing them with the `\` character.

# %%
another_pun = "The first time I got a universal remote control, I thought to myself \" This changes everything\"."

# %%
another_pun
# Out:
# 'The first time I got a universal remote control, I thought to myself " This changes everything".'

# %% [markdown]
# Strings created using single or double quotes must begin and end on the same line. To create multiline strings, use three single quotes `'''` or three double quotes `"""` to begin and end the string. Line breaks are represented using the newline character `\n`.

# %%
yet_another_pun = '''Son : "Dad, can you tell me what a solar eclispeis?"
Dad: "No sun."'''

# %%
yet_another_pun
# Out:
# 'Son : "Dad, can you tell me what a solar eclispeis?"\nDad: "No sun."'

# %% [markdown]
# Multiline strings are best displayed using the `print` function.

# %%
print(yet_another_pun)
# Out:
# Son : "Dad, can you tell me what a solar eclispeis?"
# Dad: "No sun."

# %%
a_music_pun = """
Two windmills are standing in a field and one asks the other,
"What kind of music do you like?"

The other says,
"I'm a big metal fan."
"""

# %%
print(a_music_pun)
# Out:
# Two windmills are standing in a field and one asks the other,
# "What kind of music do you like?"
#
# The other says,
# "I'm a big metal fan."

# %%
len(my_favorite_series)
# Out:
# 21

# %% [markdown]
# Note that special characters like `\n` and escaped characters like `\"` count as a single character, even though they are written and sometimes printed as two characters.

# %%
multiline_string = """a
b"""
multiline_string
# Out:
# 'a\nb'

# %% [markdown]
# A string can be converted into a list of characters using `list` function

# %%
list(multiline_string)
# Out:
# ['a', '\n', 'b']

# %% [markdown]
# Strings also support several list operations.
# e.g. Slicing.
#
# You can access individual characters within a string using the `[]` indexing notation. Note the character indices go from `0` to `n-1`, where `n` is the length of the string.

# %%
today = "Friday"

# %%
today[0]
# Out:
# 'F'

# %%
today[3]
# Out:
# 'd'

# %% [markdown]
# You can access a part of a string using by providing a `start:end` range instead of a single index in `[]`.

# %%
today[3::]
# Out:
# 'day'

# %% [markdown]
# You can also check whether a string contains some text using `in` operator

# %%
'day' in today
# Out:
# True

# %%
'Fri' in today
# Out:
# True

# %% [markdown]
# Two or more strings can be joined or *concatenated* using the `+` operator. Be careful while concatenating strings, sometimes you may need to add a space character `" "` between words

# %%
full_name = 'Saniya Shaikh'

# %%
greeting = 'Hello!'

# %%
print(greeting + full_name)
# Out:
# Hello!Saniya Shaikh

# %%
print(greeting + " " + full_name) # additional space
# Out:
# Hello! Saniya Shaikh

# %% [markdown]
# Strings in Python have many built-in *methods* that are used to manipulate them. Let's try out some common string methods.
#
# > **Methods**: Methods are functions associated with data types and are accessed using the `.` notation e.g. `variable_name.method()` or `"a string".method()`. Methods are a powerful technique for associating common operations with values of specific data types.
#
# The `.lower()`, `.upper()` and `.capitalize()` methods are used to change the case of the characters.

# %%
today.lower()
# Out:
# 'friday'

# %%
'Wednesday'.upper()
# Out:
# 'WEDNESDAY'

# %%
'tuesDay'.capitalize() # similar to PROPER in excel
# Out:
# 'Tuesday'

# %% [markdown]
# The `.replace` method replaces a part of the string with another string. It takes the portion to be replaced and the replacement text as *inputs* or *arguments*.
#
# Note that `replace` returns a new string, and the original string is not modified.

# %%
another_day = today.replace('Fri', 'Satur')

# %%
another_day
# Out:
# 'Saturday'

# %% [markdown]
# The `.split` method splits a string into a list of strings at every occurrence of provided character(s).

# %%
a_long_line = "       This is a long line with some space before, after,     and some space in the middle..    "

# %%
a_long_line_stripped = a_long_line.strip()

# %%
a_long_line_stripped
# Out:
# 'This is a long line with some space before, after,     and some space in the middle..'

# %% [markdown]
# The `.format` method combines values of other data types, e.g., integers, floats, booleans, lists, etc. with strings. You can use `format` to construct output messages for display.

# %%
# Input variables
cost_of_ice_bag = 1.25
profit_margin = 0.2
no_of_bags = 500

# Template for output message
output_template = """If a grocery store sells ice bags at $ {} per bag, with a profit margin of {} %,
then the total profit it makes by selling {} ice bags is $ {}."""

print(output_template)
# Out:
# If a grocery store sells ice bags at $ {} per bag, with a profit margin of {} %,
# then the total profit it makes by selling {} ice bags is $ {}.

# %%
# Inserting values iny=to the sBytesWarning
total_profit = cost_of_ice_bag * profit_margin * no_of_bags
output_message = output_template.format(cost_of_ice_bag, profit_margin * 100, no_of_bags, total_profit)

print(output_message)
# Out:
# If a grocery store sells ice bags at $ 1.25 per bag, with a profit margin of 20.0 %,
# then the total profit it makes by selling 500 ice bags is $ 125.0.

# %% [markdown]
# Notice how the placeholders `{}` in the `output_template` string are replaced with the arguments provided to the `.format` method.
#
# It is also possible to use the string concatenation operator `+` to combine strings with other values. However, those values must first be converted to strings using the `str` function.

# %%
"If a grocery store sells ice bags at $ " + cost_of_ice_bag + ", with a profit margin of " + profit_margin
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 "If a grocery store sells ice bags at $ " + cost_of_ice_bag + ", with a profit margin of " + profit_margin
#
# TypeError: can only concatenate str (not "float") to str

# %%
"If a grocery store sells ice bags at $ " + str(cost_of_ice_bag) + ", with a profit margin of " + str(profit_margin)
# Out:
# 'If a grocery store sells ice bags at $ 1.25, with a profit margin of 0.2'

# %%
str(23)
# Out:
# '23'

# %%
str(23.432)
# Out:
# '23.432'

# %%
str(True)
# Out:
# 'True'

# %%
the_3_musketeers = ["Athos", "Porthos", "Aramis"]
str(the_3_musketeers)
# Out:
# "['Athos', 'Porthos', 'Aramis']"

# %% [markdown]
# Note that all string methods return new values and DO NOT change the existing string.

# %% [markdown]
# Strings also support the comparison operators `==` and `!=` for checking whether two strings are equal.

# %%
f_name = 'Saniya'

# %%
f_name == 'Shaikh'
# Out:
# False

# %%
f_name != 'Shaikh'
# Out:
# True

# %%
f_name == "Saniya"
# Out:
# True

# %%
f_name != "Zahid"
# Out:
# True

# %%
f_name != "Saniya"
# Out:
# False

# %% [markdown]
# ### List
#
# A list in Python is an ordered collection of values. Lists can hold values of different data types and support operations to add, remove, and change values. Lists have the type `list`.
#
# To create a list, enclose a sequence of values within square brackets `[` and `]`, separated by commas.

# %%
fruits = ['apple', 'mango', 'banana']

# %%
fruits
# Out:
# ['apple', 'mango', 'banana']

# %%
type(fruits)
# Out:
# list

# %%
# list containing values of different data types
a_list = [54, 'Saniya', None, 3.14, fruits, 3 <= 9]

# %%
a_list
# Out:
# [54, 'Saniya', None, 3.14, ['apple', 'mango', 'banana'], True]

# %%
empty_list = []

# %%
empty_list
# Out:
# []

# %%
len(fruits)
# Out:
# 3

# %%
print("Number of fruits:  ", len(fruits))
# Out:
# Number of fruits:   3

# %%
len(a_list)
# Out:
# 6

# %%
fruits
# Out:
# ['apple', 'mango', 'banana']

# %%
a_list
# Out:
# [54, 'Saniya', None, 3.14, ['apple', 'mango', 'banana'], True]

# %%
fruits[2]
# Out:
# 'banana'

# %%
fruits[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 fruits[3]
#
# IndexError: list index out of range

# %%
fruits[-1]
# Out:
# 'banana'

# %%
fruits[-3]
# Out:
# 'apple'

# %%
a_list
# Out:
# [54, 'Saniya', None, 3.14, ['apple', 'mango', 'banana'], True]

# %%
a_list[3::]
# Out:
# [3.14, ['apple', 'mango', 'banana'], True]

# %%
a_list[2:10]
# Out:
# [None, 3.14, ['apple', 'mango', 'banana'], True]

# %%
a_list[3:]
# Out:
# [3.14, ['apple', 'mango', 'banana'], True]

# %%
a_list[:6]
# Out:
# [54, 'Saniya', None, 3.14, ['apple', 'mango', 'banana'], True]

# %%
a_list[-5:-2]
# Out:
# ['Saniya', None, 3.14]

# %% [markdown]
# Can also change the value in list using assignment operator

# %%
fruits = ['apple', 'mango', 'banana']

# %%
fruits
# Out:
# ['apple', 'mango', 'banana']

# %%
fruits[1] = "cherry"

# %%
fruits
# Out:
# ['apple', 'cherry', 'banana']

# %% [markdown]
# A new value can be added to the end of a list using the `append` method.

# %%
fruits.append('mango')

# %%
fruits
# Out:
# ['apple', 'cherry', 'banana', 'mango']

# %% [markdown]
# A new value can also be inserted at a specific index using the `insert` method.

# %%
fruits.insert(3, 'grapes')

# %%
fruits
# Out:
# ['apple', 'cherry', 'banana', 'grapes', 'mango']

# %%
fruits.remove('cherry')

# %%
fruits
# Out:
# ['apple', 'banana', 'grapes', 'mango']

# %%
fruits.remove('apple', 'banana')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[174], line 1
# ----> 1 fruits.remove('apple', 'banana')
#
# TypeError: list.remove() takes exactly one argument (2 given)

# %%
fruits = ['apple', 'banana', 'grapes', 'mango']

# %% [markdown]
# To remove an element from a specific index, use the `pop` method. The method also returns the removed element.

# %%
fruits.pop(0)
# Out:
# 'apple'

# %%
fruits
# Out:
# ['banana', 'grapes', 'mango']

# %% [markdown]
# You can test whether a list contains a value using the `in` operator.

# %%
'pineapple' in fruits
# Out:
# False

# %%
'grapes' in fruits
# Out:
# True

# %% [markdown]
# To combine two or more lists, use the `+` operator. This operation is also called *concatenation*.

# %%
fruits
# Out:
# ['banana', 'grapes', 'mango']

# %%
more_fruits = fruits + ['pineapple', 'apple', 'cherry'] + ['blueberry', 'watermelon', 'papaya', 'iceapple']

# %%
more_fruits
# Out:
# ['banana',
#  'grapes',
#  'mango',
#  'pineapple',
#  'apple',
#  'cherry',
#  'blueberry',
#  'watermelon',
#  'papaya',
#  'iceapple']

# %% [markdown]
# To create a copy of a list, use the `copy` method. Modifying the copied list does not affect the original.

# %%
more_fruits_copy = more_fruits.copy()

# %%
more_fruits_copy
# Out:
# ['banana',
#  'grapes',
#  'mango',
#  'pineapple',
#  'apple',
#  'cherry',
#  'blueberry',
#  'watermelon',
#  'papaya',
#  'iceapple']

# %%
# Modify copied list
more_fruits_copy.remove('cherry')

# %%
more_fruits_copy.pop()
# Out:
# 'iceapple'

# %%
more_fruits_copy
# Out:
# ['banana',
#  'grapes',
#  'mango',
#  'pineapple',
#  'apple',
#  'blueberry',
#  'watermelon',
#  'papaya']

# %%
# Original list remains unchanged
more_fruits
# Out:
# ['banana',
#  'grapes',
#  'mango',
#  'pineapple',
#  'apple',
#  'cherry',
#  'blueberry',
#  'watermelon',
#  'papaya',
#  'iceapple']

# %% [markdown]
# Note that you cannot create a copy of a list by simply creating a new variable using the assignment operator `=`. The new variable will point to the same list, and any modifications performed using either variable will affect the other.

# %%
more_fruits_not_copy = more_fruits

# %%
more_fruits_not_copy.remove('cherry')

# %%
more_fruits_not_copy.pop()
# Out:
# 'iceapple'

# %%
more_fruits
# Out:
# ['banana',
#  'grapes',
#  'mango',
#  'pineapple',
#  'apple',
#  'blueberry',
#  'watermelon',
#  'papaya']

# %%
more_fruits_not_copy
# Out:
# ['banana',
#  'grapes',
#  'mango',
#  'pineapple',
#  'apple',
#  'blueberry',
#  'watermelon',
#  'papaya']

# %% [markdown]
# Just like strings, there are several in-built methods to manipulate a list. However, unlike strings, most list methods modify the original list rather than returning a new one.
#
# Following are some exercises you can try out with list methods (use the blank code cells below):
#
# * Reverse the order of elements in a list
# * Add the elements of one list at the end of another list
# * Sort a list of strings in alphabetical order
# * Sort a list of numbers in decreasing order

# %%
more_fruits = ['banana', 'grapes', 'mango', 'pineapple', 'apple', 'cherry', 'blueberry', 'watermelon', 'papaya', 'iceapple']

# %%
more_fruits.reverse()

# %%
more_fruits
# Out:
# ['iceapple',
#  'papaya',
#  'watermelon',
#  'blueberry',
#  'cherry',
#  'apple',
#  'pineapple',
#  'mango',
#  'grapes',
#  'banana']

# %%
more_fruits = more_fruits + fruits

# %%
more_fruits
# Out:
# ['iceapple',
#  'papaya',
#  'watermelon',
#  'blueberry',
#  'cherry',
#  'apple',
#  'pineapple',
#  'mango',
#  'grapes',
#  'banana',
#  'banana',
#  'grapes',
#  'mango']

# %%
more_fruits.sort()

# %%
more_fruits
# Out:
# ['apple',
#  'banana',
#  'banana',
#  'blueberry',
#  'cherry',
#  'grapes',
#  'grapes',
#  'iceapple',
#  'mango',
#  'mango',
#  'papaya',
#  'pineapple',
#  'watermelon']

# %%
more_fruits.sort(reverse = True)

# %%
more_fruits
# Out:
# ['watermelon',
#  'pineapple',
#  'papaya',
#  'mango',
#  'mango',
#  'iceapple',
#  'grapes',
#  'grapes',
#  'cherry',
#  'blueberry',
#  'banana',
#  'banana',
#  'apple']

# %%
numbered_list = [ 4,7,1,9,2,32,8,97,32,754]

# %%
numbered_list.sort(reverse = True)

# %%
numbered_list
# Out:
# [754, 97, 32, 32, 9, 8, 7, 4, 2, 1]

# %% [markdown]
# ### Tuple
#
# A tuple is an ordered collection of values, similar to a list. However, it is not possible to add, remove, or modify values in a tuple. A tuple is created by enclosing values within parentheses `(` and `)`, separated by commas.
#
# > Any data structure that cannot be modified after creation is called *immutable*. You can think of tuples as immutable lists.
#
# Let's try some experiments with tuples.

# %%
fruits = ('apple', 'mango', 'banana', 'grapes')

# %%
type(fruits)
# Out:
# tuple

# %%
len(fruits)
# Out:
# 4

# %%
fruits[2]
# Out:
# 'banana'

# %%
fruits[-1]
# Out:
# 'grapes'

# %%
'dates' in fruits
# Out:
# False

# %%
# try to change an element
fruits[0] = 'avocado'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[211], line 2
#       1 # try to change an element
# ----> 2 fruits[0] = 'avocado'
#
# TypeError: 'tuple' object does not support item assignment

# %%
fruits.append('blueberry')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[212], line 1
# ----> 1 fruits.append('blueberry')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
# try to remove an element
fruits.remove('apple')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[213], line 2
#       1 # try to remove an element
# ----> 2 fruits.remove('apple')
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %% [markdown]
# You can also skip the parantheses `(` and `)` while creating a tuple. Python automatically converts comma-separated values into a tuple.

# %%
the_3_muskeeters = 'Athos', 'Porthos', 'Aramis'

# %%
type(the_3_muskeeters)
# Out:
# tuple

# %%
the_3_muskeeters
# Out:
# ('Athos', 'Porthos', 'Aramis')

# %% [markdown]
# You can also create a tuple with just one element by typing a comma after it. Just wrapping it with parentheses `(` and `)` won't make it a tuple.

# %%
single_element_tuple = 4,

# %%
single_element_tuple
# Out:
# (4,)

# %%
type(single_element_tuple)
# Out:
# tuple

# %%
another_single_element_tuple = (5,)

# %%
another_single_element_tuple
# Out:
# (5,)

# %%
type(another_single_element_tuple)
# Out:
# tuple

# %%
not_a_tuple = (4)

# %%
type(not_a_tuple)
# Out:
# int

# %%
not_a_tuple
# Out:
# 4

# %% [markdown]
# Tuples are often used to create multiple variables with a single statement.

# %%
point = (3, 4)

# %%
point_x, point_y = point

# %%
point_x
# Out:
# 3

# %%
point_y
# Out:
# 4

# %% [markdown]
# You can convert a list into a tuple using the `tuple` function, and vice versa using the `list` function

# %%
a_list = [2, None, 'Saniya', 5.543]

# %%
type(a_list)
# Out:
# list

# %%
tuple(a_list)
# Out:
# (2, None, 'Saniya', 5.543)

# %%
type(a_list)
# Out:
# list

# %%
tuple([2, None, 'Saniya', 5.543])
# Out:
# (2, None, 'Saniya', 5.543)

# %%
list((2, None, 'Saniya', 5.543))
# Out:
# [2, None, 'Saniya', 5.543]

# %% [markdown]
# Tuples have just two built-in methods: `count` and `index`. Can you figure out what they do? While you look could look for documentation and examples online, there's an easier way to check a method's documentation, using the `help` function.

# %%
a_tuple = 42, "Saniya", False, None, 93, "Hello!"

# %%
help(a_tuple.count)
# Out:
# Help on built-in function count:
#
# count(value, /) method of builtins.tuple instance
#     Return number of occurrences of value.

# %%
a_tuple.count(42)
# Out:
# 1

# %% [markdown]
# Within a Jupyter notebook, you can also start a code cell with `?` and type the name of a function or method. When you execute this cell, you will see the function/method's documentation in a pop-up window.

# %%
# ?a_tuple.index
# Out:
# Signature: a_tuple.index(value, start=0, stop=9223372036854775807, /)
# Docstring:
# Return first index of value.
#
# Raises ValueError if the value is not present.
# Type:      builtin_function_or_method

# %% [markdown]
# Try using `count` and `index` with `a_tuple` in the code cells below.

# %%
a_tuple.count("Saniya")
# Out:
# 1

# %%
a_tuple.index("Saniya")
# Out:
# 1

# %% [markdown]
# ### Dictionary
#
# A dictionary is an unordered collection of items. Each item stored in a dictionary has a key and value. You can use a key to retrieve the corresponding value from the dictionary.  Dictionaries have the type `dict`.
#
# Dictionaries are often used to store many pieces of information e.g. details about a person, in a single variable. Dictionaries are created by enclosing key-value pairs within braces or curly brackets `{` and `}`.

# %%
person1 = {
    'name' : 'John Doe',
    'sex' : 'Male',
    'age' : '32',
    'married' : True
}

# %%
person1
# Out:
# {'name': 'John Doe', 'sex': 'Male', 'age': '32', 'married': True}

# %% [markdown]
# Dictionaries can also be created using the `dict` function.

# %%
person2 = dict(name = 'Saniya Shaikh', sex = 'Female', age = 21, married = False)

# %%
person2
# Out:
# {'name': 'Saniya Shaikh', 'sex': 'Female', 'age': 21, 'married': False}

# %%
type(person2)
# Out:
# dict

# %%
type(person1)
# Out:
# dict

# %% [markdown]
# Keys can be used to access values using square brackets `[` and `]`.

# %%
person1['name']
# Out:
# 'John Doe'

# %%
person2['name']
# Out:
# 'Saniya Shaikh'

# %%
person2['married']
# Out:
# False

# %% [markdown]
# If a key isn't present in the dictionary, then a `KeyError` is *thrown*.

# %%
person1['address']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[251], line 1
# ----> 1 person1['address']
#
# KeyError: 'address'

# %% [markdown]
# You can also use the `get` method to access the value associated with a key.

# %%
person2.get('name')
# Out:
# 'Saniya Shaikh'

# %% [markdown]
# The `get` method also accepts a default value, returned if the key is not present in the dictionary.

# %%
person2.get("address", "Unkown")
# Out:
# 'Unkown'

# %% [markdown]
# You can check whether a key is present in a dictionary using the `in` operator.

# %%
'name' in person1
# Out:
# True

# %%
'address' in person1
# Out:
# False

# %% [markdown]
# You can change the value associated with a key using the assignment operator.

# %%
person2['married']
# Out:
# False

# %%
person2['married'] = False

# %%
person2
# Out:
# {'name': 'Saniya Shaikh', 'sex': 'Female', 'age': 21, 'married': False}

# %% [markdown]
# The assignment operator can also be used to add new key-value pairs to the dictionary.

# %%
person1
# Out:
# {'name': 'John Doe', 'sex': 'Male', 'age': '32', 'married': True}

# %%
person1['address'] = '123, xyz road, abc building'

# %%
person1
# Out:
# {'name': 'John Doe',
#  'sex': 'Male',
#  'age': '32',
#  'married': True,
#  'address': '123, xyz road, abc building'}

# %%
person1.pop('address')
# Out:
# '123, xyz road, abc building'

# %%
person1
# Out:
# {'name': 'John Doe', 'sex': 'Male', 'age': '32', 'married': True}

# %%
person1.keys()
# Out:
# dict_keys(['name', 'sex', 'age', 'married'])

# %%
person1.values()
# Out:
# dict_values(['John Doe', 'Male', '32', True])

# %%
person1.items()
# Out:
# dict_items([('name', 'John Doe'), ('sex', 'Male'), ('age', '32'), ('married', True)])

# %% [markdown]
# The results of `keys`, `values`, and `items` look like lists. However, they don't support the indexing operator `[]` for retrieving elements.

# %%
person1.items()[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[267], line 1
# ----> 1 person1.items()[1]
#
# TypeError: 'dict_items' object is not subscriptable

# %%
keys_list = list(person1.keys())

# %%
keys_list[3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[268], line 1
# ----> 1 keys_list[3]
#
# NameError: name 'keys_list' is not defined

# %%
values_list = list(person1.values())

# %%
values_list[3]
# Out:
# True

# %% [markdown]
# Here are some experiments you can try out with dictionaries (use the empty cells below):
# * What happens if you use the same key multiple times while creating a dictionary?
# * How can you create a copy of a dictionary (modifying the copy should not change the original)?
# * Can the value associated with a key itself be a dictionary?
# * How can you add the key-value pairs from one dictionary into another dictionary? Hint: See the `update` method.
# * Can the dictionary's keys be something other than a string, e.g., a number, boolean, list, etc.?

# %%
student_profile = {
    "id": 101,
    "name": "Saniya",
    "branch": "Data Science",
    "marks": [85, 90, 88],
    "is_active": True
}

# %%
student = student_profile.copy()

# %%
student
# Out:
# {'id': 101,
#  'name': 'Saniya',
#  'branch': 'Data Science',
#  'marks': [85, 90, 88],
#  'is_active': True}

# %%
student = {
    'name' : 'Saniya',
    'name' : 'Zahid',
    'name' : 'Abid',
    'name' : 'Habibunnisa'
}

# %%
student['name']
# Out:
# 'Habibunnisa'

# %%
student_profile = {
    'id' : 2704,
    'name' : "Saniya Shaikh",
    'marks' : {
        'math' : 59,
        'science' : 48,
        'history' : 37
    }
}

# %%
student_profile
# Out:
# {'id': 2704,
#  'name': 'Saniya Shaikh',
#  'marks': {'math': 59, 'science': 48, 'history': 37}}

# %%
print(student_profile['marks']['math'])
# Out:
# 59

# %%
dict1 = {
    'a' : 1, 
    'b' : 2, 
    'c' : 4
}

dict2 = {
    'c' : 3, 
    'd' : 4,
    'e' : 5
}

dict1.update(dict2)

# %%
dict1
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}
