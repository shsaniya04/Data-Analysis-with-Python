# %% [markdown]
# ## **Zomato Dataset - Exploratory Data Analysis**

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %%
df = pd.read_csv("zomato_dataset/zomato.csv", encoding = "latin-1")

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   str
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   str
#  4   Address               9551 non-null   str
#  5   Locality              9551 non-null   str
#  6   Locality Verbose      9551 non-null   str
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   str
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   str
#  12  Has Table booking     9551 non-null   str
#  13  Has Online delivery   9551 non-null   str
#  14  Is delivering now     9551 non-null   str
#  15  Switch to order menu  9551 non-null   str
#  16  Price range           9551 non-null   int64
#  17  Aggregate rating      9551 non-null   float64
#  18  Rating color          9551 non-null   str
#  19  Rating text           9551 non-null   str
#  20  Votes                 9551 non-null   int64
# dtypes: float64(3), int64(5), str(13)
# memory usage: 1.5 MB

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
[features for features in df.columns if df[features].isnull().sum() > 0]
# Out:
# ['Cuisines']

# %%
sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')
# Out:
# <Axes: >

# %%
df_country = pd.read_excel("zomato_dataset/Country-Code.xlsx")

# %%
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df_merged = pd.merge(df, df_country, on = 'Country Code', how = 'left')

# %%
df_merged.sample(10)
# Out:
#       Restaurant ID                  Restaurant Name  Country Code       City  \
# 3537           3125                           Gyan's             1  New Delhi
# 4589           1931                  Spicy by Nature             1  New Delhi
# 4293       18372578                             RSVP             1  New Delhi
# 3660         311584                       Baking Bad             1  New Delhi
# 8809         307841                     Flying Cakes             1      Noida
# 1085       18365998                 The Grill Darbar             1  Faridabad
# 6514       18352180  Ok Indian & Chinese Food Corner             1  New Delhi
# 2482       18458563               The American Joint             1     Mumbai
# 2960         309080                Chulha Punjabi Da             1  New Delhi
# 4985       18222557                             Icon             1  New Delhi
#
#                                                 Address  \
# 3537  28/10, Central Market, Opposite Neel Kanth Man...
# 4589  15/A 55, WEA, Saraswati Marg, Karol Bagh, New ...
# 4293  Hotel The Royal Plaza, 19, Ashoka Road, Janpat...
# 3660                  Greater Kailash (GK) 1, New Delhi
# 8809  Shop 37, Kanchanjunga Market, Near Shoprix Mal...
# 1085  Shop 87, Near Omaxe Heights, Gate 2, Sector 86...
# 6514  Shop A RZ-53/54, Gali 14, Pankha Road, R K Pur...
# 2482  The Ahcl Homes Tower, Chikuwadi New Link Road,...
# 2960  36, C.S.C, Market 2, Chittaranjan Park, New Delhi
# 4985           27, Main Market, Lodhi Colony, New Delhi
#
#                     Locality                   Locality Verbose  Longitude  \
# 3537        East Patel Nagar        East Patel Nagar, New Delhi  77.173320
# 4589              Karol Bagh              Karol Bagh, New Delhi  77.188508
# 4293                 Janpath                 Janpath, New Delhi  77.217073
# 3660  Greater Kailash (GK) 1  Greater Kailash (GK) 1, New Delhi  77.242273
# 8809               Sector 53                   Sector 53, Noida  77.362366
# 1085               Sector 86               Sector 86, Faridabad  77.336660
# 6514               R K Puram               R K Puram, New Delhi  77.100442
# 2482           Borivali West              Borivali West, Mumbai  72.841347
# 2960       Chittaranjan Park       Chittaranjan Park, New Delhi  77.253271
# 4985            Lodhi Colony            Lodhi Colony, New Delhi  77.223765
#
#        Latitude                               Cuisines  ...  \
# 3537  28.646254                           North Indian  ...
# 4589  28.647724         North Indian, Mughlai, Chinese  ...
# 4293  28.621276                            Finger Food  ...
# 3660  28.548654                         Pizza, Italian  ...
# 8809  28.595570                                 Bakery  ...
# 1085  28.408057         North Indian, Mughlai, Chinese  ...
# 6514  28.609135                           North Indian  ...
# 2482  19.223840  Healthy Food, American, Burger, Salad  ...
# 2960  28.536343       North Indian, Chinese, Fast Food  ...
# 4985  28.584590                  Chinese, North Indian  ...
#
#       Has Table booking Has Online delivery Is delivering now  \
# 3537                 No                 Yes                No
# 4589                Yes                  No                No
# 4293                 No                  No                No
# 3660                 No                 Yes                No
# 8809                 No                 Yes                No
# 1085                 No                  No                No
# 6514                 No                  No                No
# 2482                Yes                  No                No
# 2960                 No                 Yes                No
# 4985                Yes                  No                No
#
#      Switch to order menu Price range Aggregate rating  Rating color  \
# 3537                   No           2              3.4        Orange
# 4589                   No           2              2.7        Orange
# 4293                   No           4              2.7        Orange
# 3660                   No           3              3.8        Yellow
# 8809                   No           1              2.1           Red
# 1085                   No           2              3.3        Orange
# 6514                   No           1              0.0         White
# 2482                   No           2              3.4        Orange
# 2960                   No           2              2.4           Red
# 4985                   No           3              3.2        Orange
#
#       Rating text Votes Country
# 3537      Average    93   India
# 4589      Average    84   India
# 4293      Average    16   India
# 3660         Good   697   India
# 8809         Poor    56   India
# 1085      Average    17   India
# 6514    Not rated     0   India
# 2482      Average   170   India
# 2960         Poor    41   India
# 4985      Average    18   India
#
# [10 rows x 22 columns]

# %%
df_merged.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name             str
# Country Code              int64
# City                        str
# Address                     str
# Locality                    str
# Locality Verbose            str
# Longitude               float64
# Latitude                float64
# Cuisines                    str
# Average Cost for two      int64
# Currency                    str
# Has Table booking           str
# Has Online delivery         str
# Is delivering now           str
# Switch to order menu        str
# Price range               int64
# Aggregate rating        float64
# Rating color                str
# Rating text                 str
# Votes                     int64
# Country                     str
# dtype: object

# %%
df_merged.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='str')

# %%
df_merged.Country.value_counts().index
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'UAE',
#        'South Africa', 'New Zealand', 'Turkey', 'Australia', 'Phillipines',
#        'Indonesia', 'Singapore', 'Qatar', 'Sri Lanka', 'Canada'],
#       dtype='str', name='Country')
